# %% [markdown]
# <a href="https://colab.research.google.com/github/moli-debugger/opencvproject/blob/master/Python_graphic_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import*

# %%
initializeTurtle(initial_speed =10)
bgcolor('black')
color('white')
a=0
b=0
speed(10)
penup()
goto(0,200)
pendown()
while True:
  forward(a)
  right(b)
  a+=3
  b+=1
  if b==210:
   break
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
